# %%
salariofixo = float(input("Informe seu salário fixo: "))
totalvendas = float(input("Informe o total de vendas: "))
comissao = int(input("Sua comissão: "))

salariofinal = salariofixo + ((comissao/100) * totalvendas)
print("Seu salário final é: ", salariofinal)
# Out:
# Informe seu salário fixo: 90
# Informe o total de vendas: 900
# Sua comissão: 80
# Seu salário final é:  810.0
