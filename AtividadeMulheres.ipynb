# %%
filhos1 = filhos2 = 0


def menu():
  global filhos
  filhos = int(input("Digite o número de filhos que você possui: "))

for i in range (10):
  menu()

  if filhos > 2:
    filhos1 = filhos1 + 1
  else:
    filhos2 = filhos2 + 1

print("O número de mulheres com dois ou menos filhos é: ", filhos2)
print("O número de mulheres com mais de dois filhos é: ", filhos1)
# Out:
# Digite o número de filhos que você possui: 2
# Digite o número de filhos que você possui: 2
# Digite o número de filhos que você possui: 2
# Digite o número de filhos que você possui: 2
# Digite o número de filhos que você possui: 4
# Digite o número de filhos que você possui: 5
# Digite o número de filhos que você possui: 5
# Digite o número de filhos que você possui: 5
# Digite o número de filhos que você possui: 5
# Digite o número de filhos que você possui: 5
# O número de mulheres com dois ou menos filhos é:  4
# O número de mulheres com mais de dois filhos é:  6
