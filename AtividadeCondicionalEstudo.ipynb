# %%
horas_estudadas = int((input("Insira a quantidade de horas estudadas durante o dia: ")))

if (horas_estudadas < 4):
  print("Estude um pouco mais!")

elif (horas_estudadas > 8):
  print("Parabéns!!")

else:
  print("Muito massa!")
# Out:
# Insira a quantidade de horas estudadas durante o dia: 90
# Parabéns!!
