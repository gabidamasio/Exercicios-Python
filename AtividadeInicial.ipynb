# %%
nome = (input("Informe seu nome: "))
salario = (float(input("Informe seu salário: ")))
aulas = (int(input("Informe o números de aulas ministradas por mês: ")))

print("Nome: ", nome, "\nSalário:", salario, "\nAulas: ", aulas)
# Out:
# Informe seu nome: gab
# Informe seu salário: 564568
# Informe o números de aulas ministradas por mês: 34
# Nome:  gab
# Salário: 564568.0
# Aulas:  34
