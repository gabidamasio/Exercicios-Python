# %%
acumulador=0

while True:
  num = int(input("Informe um número possitivo ou aperte 0 para sair "))

  if num < 0:
    print("Número inválido!")
    continue
  elif num == 0:
    break
  acumulador = acumulador + num
  print ("A soma dos números inseridos foi: ", acumulador)
# Out:
# Informe um número possitivo ou aperte 0 para sair 7
# A soma dos números inseridos foi:  7
# Informe um número possitivo ou aperte 0 para sair 8
# A soma dos números inseridos foi:  15
# Informe um número possitivo ou aperte 0 para sair 9
# A soma dos números inseridos foi:  24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5e0805a54940> in <cell line: 3>()
#       2
#       3 while True:
# ----> 4   num = int(input("Informe um número possitivo ou aperte 0 para sair "))
#       5
#       6   if num < 0:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
